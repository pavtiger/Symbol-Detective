# %%
# !pip install tensorflow==2.4.0
# !pip install tensorflow-gpu==2.4.0
# !pip install keras==2.4.3 numpy==1.19.3 pillow==7.0.0 scipy==1.4.1 h5py==2.10.0 matplotlib==3.3.2 opencv-python keras-resnet==0.2.0
# !pip install imageai --upgrade

# %%
# !apt install neofetch -y --quiet
# !neofetch

# %%
# !ls ../input/symbol-vertices
# !cp -r ../input/symbol-vertices/Symbol-Recognition ./

# %%
ls /kaggle/working/Symbol-Recognition/'Symbol Recognition.v3i.voc'/

# %%
# !wget "https://github.com/OlafenwaMoses/ImageAI/releases/download/essential-v4/pretrained-yolov3.h5"

# %%
# !nvidia-smi

# %%
from imageai.Detection.Custom import DetectionModelTrainer
import tensorflow as tf


trainer = DetectionModelTrainer()
trainer.setModelTypeAsYOLOv3()
trainer.setDataDirectory(data_directory="./Symbol-Recognition/Symbol Recognition.v3i.voc")
trainer.setTrainConfig(object_names_array=["vertex"], batch_size=8, num_experiments=120, train_from_pretrained_model="./pretrained-yolov3.h5")

trainer.trainModel()
